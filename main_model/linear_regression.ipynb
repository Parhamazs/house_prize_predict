# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn

# %% [markdown]
# ## مرحله خواندن و پردازش داده ها :
# - داده رو دریافت می کنیم
# - اطلاعات اولیه را از آن بدست می آوریم

# %%
data = pd.read_csv('housePrice.csv')

# %%
data.head()
# Out:
#   Area  Room  Parking  Warehouse  Elevator         Address         Price  \
# 0   63     1     True       True      True         Shahran  1.850000e+09
# 1   60     1     True       True      True         Shahran  1.850000e+09
# 2   79     2     True       True      True          Pardis  5.500000e+08
# 3   95     2     True       True      True   Shahrake Qods  9.025000e+08
# 4  123     2     True       True      True  Shahrake Gharb  7.000000e+09
#
#    Price(USD)
# 0    61666.67
# 1    61666.67
# 2    18333.33
# 3    30083.33
# 4   233333.33

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3479 non-null   object
#  1   Room        3479 non-null   int64
#  2   Parking     3479 non-null   bool
#  3   Warehouse   3479 non-null   bool
#  4   Elevator    3479 non-null   bool
#  5   Address     3456 non-null   object
#  6   Price       3479 non-null   float64
#  7   Price(USD)  3479 non-null   float64
# dtypes: bool(3), float64(2), int64(1), object(2)
# memory usage: 146.2+ KB

# %%
data.describe()
# Out:
#               Room         Price    Price(USD)
# count  3479.000000  3.479000e+03  3.479000e+03
# mean      2.079908  5.359023e+09  1.786341e+05
# std       0.758275  8.099935e+09  2.699978e+05
# min       0.000000  3.600000e+06  1.200000e+02
# 25%       2.000000  1.418250e+09  4.727500e+04
# 50%       2.000000  2.900000e+09  9.666667e+04
# 75%       2.000000  6.000000e+09  2.000000e+05
# max       5.000000  9.240000e+10  3.080000e+06

# %%
sns.scatterplot(data)
# Out:
# <Axes: >

# %%
data.shape
# Out:
# (3479, 8)

# %%
data.columns
# Out:
# Index(['Area', 'Room', 'Parking', 'Warehouse', 'Elevator', 'Address', 'Price',
#        'Price(USD)'],
#       dtype='object')

# %%
# check for number of unique values
data.nunique()
# Out:
# Area          243
# Room            6
# Parking         2
# Warehouse       2
# Elevator        2
# Address       192
# Price         934
# Price(USD)    932
# dtype: int64

# %%
# check for null vlues
data.isnull().sum()
# Out:
# Area           0
# Room           0
# Parking        0
# Warehouse      0
# Elevator       0
# Address       23
# Price          0
# Price(USD)     0
# dtype: int64

# %% [markdown]
# ## data Manipulation:
# - دست بردن و تغییر در دیتا ها
# - مهندسی ویژگی ها و تنظیم آن ها

# %%
data.head()
# Out:
#   Area  Room  Parking  Warehouse  Elevator         Address         Price  \
# 0   63     1     True       True      True         Shahran  1.850000e+09
# 1   60     1     True       True      True         Shahran  1.850000e+09
# 2   79     2     True       True      True          Pardis  5.500000e+08
# 3   95     2     True       True      True   Shahrake Qods  9.025000e+08
# 4  123     2     True       True      True  Shahrake Gharb  7.000000e+09
#
#    Price(USD)
# 0    61666.67
# 1    61666.67
# 2    18333.33
# 3    30083.33
# 4   233333.33

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# convert categorical to numerical values

data['Parking'] = le.fit_transform(data.Parking)
data['Warehouse'] = le.fit_transform(data.Warehouse)
data['Elevator'] = le.fit_transform(data.Elevator)

# %%
data.describe()
# Out:
#               Room      Parking    Warehouse     Elevator         Price  \
# count  3479.000000  3479.000000  3479.000000  3479.000000  3.479000e+03
# mean      2.079908     0.847945     0.914631     0.787295  5.359023e+09
# std       0.758275     0.359126     0.279471     0.409279  8.099935e+09
# min       0.000000     0.000000     0.000000     0.000000  3.600000e+06
# 25%       2.000000     1.000000     1.000000     1.000000  1.418250e+09
# 50%       2.000000     1.000000     1.000000     1.000000  2.900000e+09
# 75%       2.000000     1.000000     1.000000     1.000000  6.000000e+09
# max       5.000000     1.000000     1.000000     1.000000  9.240000e+10
#
#          Price(USD)
# count  3.479000e+03
# mean   1.786341e+05
# std    2.699978e+05
# min    1.200000e+02
# 25%    4.727500e+04
# 50%    9.666667e+04
# 75%    2.000000e+05
# max    3.080000e+06

# %%
data.corr
# Out:
# <bound method DataFrame.corr of      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1        1          1         1             Shahran
# 1      60     1        1          1         1             Shahran
# 2      79     2        1          1         1              Pardis
# 3      95     2        1          1         1       Shahrake Qods
# 4     123     2        1          1         1      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2        1          1         1  Southern Janatabad
# 3475   83     2        1          1         1            Niavaran
# 3476   75     2        0          0         0              Parand
# 3477  105     2        1          1         1              Dorous
# 3478   82     2        0          1         1              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3479 non-null   object
#  1   Room        3479 non-null   int64
#  2   Parking     3479 non-null   int64
#  3   Warehouse   3479 non-null   int64
#  4   Elevator    3479 non-null   int64
#  5   Address     3456 non-null   object
#  6   Price       3479 non-null   float64
#  7   Price(USD)  3479 non-null   float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 217.6+ KB

# %%
data = data.drop('Address',axis=1)

# %%
data.shape
# Out:
# (3479, 7)

# %%
data.head()
# Out:
#   Area  Room  Parking  Warehouse  Elevator         Price  Price(USD)
# 0   63     1        1          1         1  1.850000e+09    61666.67
# 1   60     1        1          1         1  1.850000e+09    61666.67
# 2   79     2        1          1         1  5.500000e+08    18333.33
# 3   95     2        1          1         1  9.025000e+08    30083.33
# 4  123     2        1          1         1  7.000000e+09   233333.33

# %%
data['Price'] = data['Price'].astype('float64')

# %%
data.head()
# Out:
#   Area  Room  Parking  Warehouse  Elevator         Price  Price(USD)
# 0   63     1        1          1         1  1.850000e+09    61666.67
# 1   60     1        1          1         1  1.850000e+09    61666.67
# 2   79     2        1          1         1  5.500000e+08    18333.33
# 3   95     2        1          1         1  9.025000e+08    30083.33
# 4  123     2        1          1         1  7.000000e+09   233333.33

# %%
data.corr
# Out:
# <bound method DataFrame.corr of      Area  Room  Parking  Warehouse  Elevator         Price  Price(USD)
# 0      63     1        1          1         1  1.850000e+09    61666.67
# 1      60     1        1          1         1  1.850000e+09    61666.67
# 2      79     2        1          1         1  5.500000e+08    18333.33
# 3      95     2        1          1         1  9.025000e+08    30083.33
# 4     123     2        1          1         1  7.000000e+09   233333.33
# ...   ...   ...      ...        ...       ...           ...         ...
# 3474   86     2        1          1         1  3.500000e+09   116666.67
# 3475   83     2        1          1         1  6.800000e+09   226666.67
# 3476   75     2        0          0         0  3.650000e+08    12166.67
# 3477  105     2        1          1         1  5.600000e+09   186666.67
# 3478   82     2        0          1         1  3.600000e+08    12000.00
#
# [3479 rows x 7 columns]>

# %%
data = data.drop('Price',axis=1)

# %%
data.head()
# Out:
#   Area  Room  Parking  Warehouse  Elevator  Price(USD)
# 0   63     1        1          1         1    61666.67
# 1   60     1        1          1         1    61666.67
# 2   79     2        1          1         1    18333.33
# 3   95     2        1          1         1    30083.33
# 4  123     2        1          1         1   233333.33

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,12))
sns.heatmap(data.corr(), annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 4
#       1 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(12,12))
# ----> 4 sns.heatmap(data.corr(), annot=True)
#
# File c:\Users\Raya\Documents\GitHub\house_prize_predict\venv\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Raya\Documents\GitHub\house_prize_predict\venv\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
X = data['Area']
Y = data['Price']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.3, random_state=4)

# %%
from sklearn.linear_model import LinearRegression

slr = LinearRegression()
slr.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 4
#       1 from sklearn.linear_model import LinearRegression
#       3 slr = LinearRegression()
# ----> 4 slr.fit(X_train,Y_train)
#
# File c:\Users\Raya\Documents\GitHub\house_prize_predict\venv\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Raya\Documents\GitHub\house_prize_predict\venv\Lib\site-packages\sklearn\linear_model\_base.py:601, in LinearRegression.fit(self, X, y, sample_weight)
#     597 n_jobs_ = self.n_jobs
# ...
